# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyaAhmed17/my-first-project/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
country = "sudan"
if country == "uk" or "united states" or "turkey" or "sudan":

 if country == "uk":
  print("Welcom to the UK")

 elif country=="united states":
  print("Welcom to the United States")

 elif country=="turkey":
  print("Hoş Geldiniz")

 elif country=="sudan":
  print("اهلا وسهلا بك في السودان")

  if country == "sudan":
    print("أين تعيش في السودان؟")
    state = str (input("الولاية "))
  if state == "الخرطوم" or state== "بورتسودان":
    print("حبابك عشرة")
  else:
    print("اهلا وسهلا")

 else:
    print("You're Welcom")
# Out:
# اهلا وسهلا بك في السودان
# أين تعيش في السودان؟
# الولاية الخرطوم
# حبابك عشرة
