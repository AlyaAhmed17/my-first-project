# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyaAhmed17/my-first-project/blob/main/English%20Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Grammer\n")
print("NOTE THAT: The answer should be in a capital letter, without any space ")
Question_1 = "1. Rarely ___ such a breathtaking performance in all my years as a critic."
A = 'A) I have seen'
B = 'B) have I seen'
C = 'C) I saw'
print(Question_1)
print(A)
print(B)
print(C)
Answer = str (input(" Your Answer is: "))
if Answer == ("B"):
  print(" Correct Answer ")
else:
  print ("*Wrong Answer, The Correct Answer is B ")

print("\nNOTE THAT: The answer should be in a capital letter, without any space ")
Question_2 = "2. If I _______ more careful with my finances last year, I wouldn't be in this mess now."
A = 'A) was'
B = 'B) were'
C = 'C) had been'
print(Question_2)
print(A)
print(B)
print(C)
Answer = str (input("Your answer is: "))
if Answer == ("C"):
 print (" Correct Answer")
else:
  print(" *Wrong Answer, The Correct Answer is C ")

print("\nNOTE THAT: The answer should be in a capital letter, without any space ")
Question_3 = "3. The committee recommended that the CEO _______ immediately for his misconduct."
A = 'A) apologizes'
B = 'B) apologize'
C = 'C) apologized'
print(Question_3)
print(A)
print(B)
print(C)
Answer = str (input("Your answer is: "))
if Answer == ("B"):
 print (" Correct Answer")
else:
  print(" *Wrong Answer, The Correct Answer is B ")

print("\nNOTE THAT: The answer should be in a capital letter, without any space ")
Question_4 = "4._______ I really need right now is some peace and quiet to finish this report."
A = 'A) It is'
B = 'B) What'
C = 'C) That'
print(Question_4)
print(A)
print(B)
print(C)
Answer = str (input("Your answer is: "))
if Answer == ("B"):
 print (" Correct Answer")
else:
  print(" *Wrong Answer, The Correct Answer is B ")

print("\nNOTE THAT: The answer should be in a capital letter, without any space ")
Question_5 = "5. He bought the antique book, the cover _______ was severely torn."
A = 'A) of which'
B = 'B) whose'
C = 'C) which'
print(Question_5)
print(A)
print(B)
print(C)
Answer = str (input("Your answer is: "))
if Answer == ("A"):
 print (" Correct Answer")
else:
  print(" *Wrong Answer, The Correct Answer is A ")

print("\nVocabulary\n")
print("NOTE THAT: The answer should be in a capital letter, without any space ")
Question_1 = "1. The speaker's message was so _______ that many in the audience were left confused about his true intentions."
A = 'A) Pellucid'
B = 'B) Ambiguous'
C = 'C) Lucid'
print(Question_1)
print(A)
print(B)
print(C)
Answer = str (input("Your answer is: "))
if Answer == ("B"):
 print (" Correct Answer")
else:
  print(" *Wrong Answer, The Correct Answer is B ")

print("\nNOTE THAT: The answer should be in a capital letter, without any space ")
Question_2 = "2. After years of research, the scientist is finally on the _______ of a major breakthrough."
A = 'A) Verge'
B = 'B) Rim'
C = 'C) Fringe'
print(Question_2)
print(A)
print(B)
print(C)
Answer = str (input("Your answer is: "))
if Answer == ("A"):
 print (" Correct Answer")
else:
  print(" *Wrong Answer, The Correct Answer is A ")

print("\nNOTE THAT: The answer should be in a capital letter, without any space ")
Question_3 = "3. The diplomat handled the delicate situation with great _______, ensuring that neither party felt insulted."
A = 'A) Finesse'
B = 'B) Brashness'
C = 'C) Inertia'
print(Question_3)
print(A)
print(B)
print(C)
Answer = str (input("Your answer is: "))
if Answer == ("A"):
 print (" Correct Answer")
else:
  print(" *Wrong Answer, The Correct Answer is A ")

print("\nNOTE THAT: The answer should be in a capital letter, without any space ")
Question_4 = "4. The heavy rainfall served to _______ the effects of the long drought, though more is needed."
A = 'A) Exacerbate'
B = 'B) Mitigate'
C = 'C) Adhere'
print(Question_4)
print(A)
print(B)
print(C)
Answer = str (input("Your answer is: "))
if Answer == ("B"):
 print (" Correct Answer")
else:
  print(" *Wrong Answer, The Correct Answer is B ")

print("\nNOTE THAT: The answer should be in a capital letter, without any space ")
Question_5 = "5. His argument was _______, supported by a wealth of evidence and logical reasoning."
A = 'A) Flabby'
B = 'B) Cogent'
C = 'C) Spurious'
print(Question_5)
print(A)
print(B)
print(C)
Answer = str (input("Your answer is: "))
if Answer == ("B"):
 print (" Correct Answer")
else:
  print(" *Wrong Answer, The Correct Answer is B ")

print("\nSentences\n")
Question_1 = "Question 1 (Sentence Transformation):"
print(Question_1)
print("Sentence: ""Nobody seemed to know exactly how often the buses ran.")
print("Task: Complete the second sentence using the word FREQUENCY.")
print("Completion: The _____________________________ to be known by anybody.")
task = input("The ")
if task == ("exact frequency of the buses didn't seem"):
  print (" Correct Answer")
else:
  print (" Wrong Answer, the correct answer is: exact frequency of the buses didn't seem")

Question_2 = "\nQuestion 2 (Cleft Sentences for Emphasis):"
print(Question_2)
print("Sentence: ""His determination really made the difference.")
print("Task: Rewrite starting with" " It was...")
print("Completion: It ________________________ really made the difference.")
task =(input("It "))
answer = "was his determination that"
if task == (answer):
  print (" Correct Answer")
else:
  print (" Wrong Answer, the correct answer is: was his determination that")

Question_3 = "\nQuestion 3 (Inversion with 'Only after'):"
print(Question_3)
print("Sentence: ""I only realized the importance of the project after the meeting.")
print("Task: Rewrite starting with" " Only after the meeting...")
print("Completion: Only after the meeting __________________ the importance of the project.")
task =(input("Only after the meeting "))
if task == ("did I realize"):
  print (" Correct Answer")
else:
  print (" Wrong Answer, the correct answer is: did I realize")

Question_4 = "\nQuestion 4 (Idiomatic Sentence Completions):"
print(Question_4)
print("Sentence: ""The mistake in the accounts was not noticed until the figures were re-checked.")
print("Task: Complete using the word LIGHT.")
print("Completion: The mistake in the accounts only _____________________________ the figures were re-checked")
task =(input("The mistake in the accounts only "))
answer1 = "came to light when"
answer2 = "came to light after"
if task == answer1 or answer2:
  print (" Correct Answer")
else:
  print (" Wrong Answer, the correct answer is: came to light when/after")

Question_5 = "\nQuestion 5 (Advanced Modal/Conditional Structures):"
print(Question_5)
print("Sentence: ""I would be pleased if you attended the gala.")
print("Task: Rewrite using a more formal C2 structure (Starting with 'Should').")
print("Completion: ____________________ attend, I would be pleased.")
task =(input("   "))
answer = "Should you"
if task == ("Should you"):
  print (" Correct Answer")
else:
  print (" Wrong Answer, the correct answer is: Should you")

print("\nSentence Correction\n")
print("1. The Error: ""Had I have known about the traffic, I would have taken the train.")
answer = input(" The Correction: ")
if answer == ("Had I known"):
  print (" Correct Answer")
else:
  print (" Wrong Answer, the correct answer is: Had I known")

print("\n2. The Error: ""The CEO, as well as his advisors, are attending the conference tomorrow.")
answer = input(" The Correction: ")
if answer == ("is attending"):
  print (" Correct Answer")
else:
  print (" Wrong Answer, the correct answer is: is attending")

print("\n3. The Error: ""Try as he might, but he couldn't solve the complex equation.")
answer = input(" The Correction: ")
if answer == ("Try as he might, he couldn't"):
  print (" Correct Answer")
else:
  print (" Wrong Answer, the correct answer is: Try as he might, he couldn't")

print("\n4. The Error: ""I’d rather you don’t smoke in the house, if you don't mind.")
answer = input(" The Correction: ")
if answer == ("I’d rather you didn’t smoke"):
  print (" Correct Answer")
else:
  print (" Wrong Answer, the correct answer is: I’d rather you didn’t smoke")

print("\n5. The Error: ""Hardly had the film started when did the power go out.")
answer = input(" The Correction: ")
if answer == ("when the power went out"):
  print (" Correct Answer")
else:
  print (" Wrong Answer, the correct answer is: when the power went out")
# Out:
# Grammer
#
# NOTE THAT: The answer should be in a capital letter, without any space
# 1. Rarely ___ such a breathtaking performance in all my years as a critic.
# A) I have seen
# B) have I seen
# C) I saw
#  Your Answer is: a
# *Wrong Answer, The Correct Answer is B
#
# NOTE THAT: The answer should be in a capital letter, without any space
# 2. If I _______ more careful with my finances last year, I wouldn't be in this mess now.
# A) was
# B) were
# C) had been
# Your answer is: C
#  Correct Answer
#
# NOTE THAT: The answer should be in a capital letter, without any space
# 3. The committee recommended that the CEO _______ immediately for his misconduct.
# A) apologizes
# B) apologize
# C) apologized
# Your answer is: B
#  Correct Answer
#
# NOTE THAT: The answer should be in a capital letter, without any space
# 4._______ I really need right now is some peace and quiet to finish this report.
# A) It is
# B) What
# C) That
# Your answer is: B
#  Correct Answer
#
# ...
